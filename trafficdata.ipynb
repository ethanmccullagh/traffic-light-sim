# %%
import pandas
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
import random

data = pandas.read_csv('./clean_data.csv')

tStart = data['Start Time']

counts = []

for i in tStart: counts.append(0)

for i in ['North', 'East', 'South', 'West']:

    nS = data[i +' Straight']
    nR = data[i + ' Right']
    nL = data[i + ' Left']


    for i in range(len(tStart)):
        counts[i] += nS[i] + nR[i] + nL[i]

plt.plot(tStart, counts)
plt.xticks([i for i in range(0, 96, 12)])
plt.show()

# %%
# mean = sum(counts)/len(counts)
# print(mean)
# print()
# 
# print('Peaks')
# 
# print(tStart[77], tStart[81])
# print(sum(counts[77:81])/4)
# 
# print()
# print(tStart[17], tStart[21])
# print(sum(counts[17:21])/4)
# 
# print('Stable')
# print()
# print(tStart[21], tStart[77])
# print(sum(counts[21:77])/(77-21))

print(tStart[81], tStart[17])
print(sum(counts[:17]+counts[81:])/(81-17))

# [tStart[:17] + tStart[81:]]

X = np.array([i in range(64)])
X.reshape(1, -1)


y = np.array(sorted(counts[:17]+counts[81:]))
Y = [int(item/15) for item in y]

print(Y)
print(len(y)*0.07)
print(sum(Y)/len(Y))

print(np.unique(Y, return_counts=True))
# Out:
# 08:45 16:45
# 236.78125
# [28, 28, 28, 28, 28, 28, 29, 29, 29, 29, 29, 30, 30, 30, 31, 31, 31, 31, 32, 32, 32, 32, 33, 33, 33, 33, 33, 34, 34, 35, 35, 36]
# 2.24
# 31.0625
# (array([28, 29, 30, 31, 32, 33, 34, 35, 36]), array([6, 5, 3, 4, 4, 5, 2, 2, 1]))
